# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("/content/StudentsPerformance.csv")

# %% [markdown]
# # Exercice 1: Analyse des Tendances Centrales

# %% [markdown]
# **question1**

# %%
df["math score"].mean()  #la moyenne du math score
# Out:
# np.float64(66.089)

# %%
df["reading score"].mean()   #la moyenne du reading score
# Out:
# np.float64(69.169)

# %%
df["writing score"].mean()   #la moyenne du writing score
# Out:
# np.float64(68.054)

# %%
df["math score"].median()   #la mediane du math score
# Out:
# 66.0

# %%
df["reading score"].median()  #la mediane du reading score
# Out:
# 70.0

# %%
df["writing score"].median()   #la mediane du writing score
# Out:
# 69.0

# %%
df["math score"].mode()   #le mod du math score
# Out:
# 0    65
# Name: math score, dtype: int64

# %%
df["reading score"].mode()  #le mod du reading score
# Out:
# 0    72
# Name: reading score, dtype: int64

# %%
df["writing score"].mode()   #le mod du writing score
# Out:
# 0    74
# Name: writing score, dtype: int64

# %% [markdown]
# # Exercice 2: Analyse de la Dispersion

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# **etendu**

# %%
etendue_math_score=df["math score"].max()-df["math score"].min()
etendue_math_score
# Out:
# 100

# %%
etendue_reading_score=df["reading score"].max()-df["reading score"].min()
etendue_reading_score
# Out:
# 83

# %%
etendue_writing_score=df["writing score"].max()-df["writing score"].min()
etendue_writing_score
# Out:
# 90

# %% [markdown]
# **l'ecart type**

# %%
df["math score"].std()  #l'ecart type du math score
# Out:
# 15.163080096009468

# %%
df["reading score"].std()  #l'ecart type du reading score
# Out:
# 14.60019193725222

# %%
df["writing score"].std()  #l'ecart type du writing score
# Out:
# 15.195657010869642

# %% [markdown]
# # Exercice 3: Quartiles et IQR

# %% [markdown]
# **a) Calcul des Quartiles**

# %%
Q1=df["math score"].quantile()
Q1
# Out:
# np.float64(66.0)

# %%
Q2=df["reading score"].quantile()
Q2
# Out:
# np.float64(70.0)

# %%
Q3=df["writing score"].quantile()
Q3
# Out:
# np.float64(69.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(3.0)

# %%
Limite_inférieure=Q1-1.5*IQR
Limite_inférieure
# Out:
# np.float64(61.5)

# %%
Limite_supérieure=Q1+1.5*IQR
Limite_supérieure
# Out:
# np.float64(70.5)

# %% [markdown]
# # Exercice 4: Visualisation des Données

# %% [markdown]
# **a) Graphiques**

# %%
import plotly.express as px

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
fig=px.histogram(df,x="race/ethnicity",y=["math score","reading score","writing score"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, y=["math score","reading score","writing score"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x='race/ethnicity', y=["writing score","reading score",'math score'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **b) Analyse de la Forme**

# %%
df_long = df.melt(
id_vars="race/ethnicity",
value_vars=["writing score", "reading score", "math score"],
var_name="Subject",
value_name="Score")

# %%
fig = px.histogram(
df_long,
x="race/ethnicity",
y="Score",
color="Subject",
barmode="group",
marginal="rug")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_long = df.melt(
    id_vars="race/ethnicity",
    value_vars=["writing score", "reading score", "math score"],
    var_name="Subject",
    value_name="Score")

# %%
df_avg = df_long.groupby(["race/ethnicity", "Subject"])["Score"].mean().reset_index()
fig = px.line(
    df_avg,
    x="race/ethnicity",
    y="Score",
    color="Subject",
    markers=True)

# %%
fig.update_layout(
yaxis_title="Average Score",
xaxis_title="Race/Ethnicity")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Exercice 5: Analyse Croisée et Insights

# %% [markdown]
# **a) Corrélation entre les Scores**

# %%
df["math score"].corr(df["reading score"])
# Out:
# np.float64(0.8175796636720546)

# %%
df["math score"].corr(df["writing score"])
# Out:
# np.float64(0.8026420459498085)

# %%
df["reading score"].corr(df["writing score"])
# Out:
# np.float64(0.9545980771462476)
